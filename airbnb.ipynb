# %%
import pandas as pd
import numpy as np

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
data = pd.read_csv("D:/Data science projects/Airbnb Analysis/df.csv")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5752\4255053797.py:1: DtypeWarning: Columns (77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,134,135,136,909,910,911,912,913,914,915,916,917,918,919,920,921,922,923,924,925,926,927,928,929,930,931,932,933,934,935,936,937,938,939,940,941,942,943,944,945,946,947,948,949,950,951,952,953,954,955,956,957,958,959,960,961,962,963,964,965,966,967,968,969,970,971,972,973,974,975,976,977,978,979,980,981,982,983,984,985,986,987,988,989,990,991,992,993,994,995,996,997,998,999,1000,1001,1002,1003,1004,1005,1006,1007,1008,1009,1010,1011,1012,1013,1014,1015,1016,1017,1018,1019,1020,1021,1022,1023,1024,1025,1026,1027,1028,1029,1030,1031,1032,1033,1034,1035,1036,1037,1038,1039,1040,1041,1042,1043,1044,1045,1046,1047,1048,1049,1050,1051,1052,1053,1054,1055,1056,1057,1058,1059,1060,1061,1062,1063,1064,1065,1066,1067,1068,1069,1070,1071,1072,1073,1074,1075,1076,1077,1078,1079,1080,1081,1082,1083,1084,1085,1086,1087,1088,1089,1090,1
# ...

# %%
data
# Out:
#       Unnamed: 0       _id                            listing_url  \
# 0              0  10009999  https://www.airbnb.com/rooms/10009999
# 1              1  10006546  https://www.airbnb.com/rooms/10006546
# 2              2  10057826  https://www.airbnb.com/rooms/10057826
# 3              3  10038496  https://www.airbnb.com/rooms/10038496
# 4              4  10082307  https://www.airbnb.com/rooms/10082307
# ...          ...       ...                                    ...
# 5550        5550   9614672   https://www.airbnb.com/rooms/9614672
# 5551        5551   9691680   https://www.airbnb.com/rooms/9691680
# 5552        5552   9759181   https://www.airbnb.com/rooms/9759181
# 5553        5553   9765083   https://www.airbnb.com/rooms/9765083
# 5554        5554   9853331   https://www.airbnb.com/rooms/9853331
#
#                                    name  \
# 0          Horto flat with small garden
# 1               Ribeira Charming Duplex
# 2                     Deluxe Loft Suite
# ...

# %%
df= pd.DataFrame(data)
df.head(2)
# Out:
#    Unnamed: 0       _id                            listing_url  \
# 0           0  10009999  https://www.airbnb.com/rooms/10009999
# 1           1  10006546  https://www.airbnb.com/rooms/10006546
#
#                            name  \
# 0  Horto flat with small garden
# 1       Ribeira Charming Duplex
#
#                                              summary  \
# 0  One bedroom + sofa-bed in quiet and bucolic ne...
# 1  Fantastic duplex apartment with three bedrooms...
#
#                                                space  \
# 0  Lovely one bedroom + sofa-bed in the living ro...
# 1  Privileged views of the Douro River and Ribeir...
#
#                                          description  \
# 0  One bedroom + sofa-bed in quiet and bucolic ne...
# 1  Fantastic duplex apartment with three bedrooms...
#
#                                neighborhood_overview  \
# 0  This charming ground floor flat is located in ...
# 1  In the neighborhood of the river, you can find...
#
# ...

# %%
df1=df[['_id','listing_url','name','property_type','room_type', 'bed_type',
       'minimum_nights', 'maximum_nights','cancellation_policy','accommodates', 'bedrooms', 'beds', 'number_of_reviews', 'bathrooms',
     'price','cleaning_fee','extra_people','guests_included','review_scores.review_scores_rating']]

df1
# Out:
#            _id                            listing_url  \
# 0     10009999  https://www.airbnb.com/rooms/10009999
# 1     10006546  https://www.airbnb.com/rooms/10006546
# 2     10057826  https://www.airbnb.com/rooms/10057826
# 3     10038496  https://www.airbnb.com/rooms/10038496
# 4     10082307  https://www.airbnb.com/rooms/10082307
# ...        ...                                    ...
# 5550   9614672   https://www.airbnb.com/rooms/9614672
# 5551   9691680   https://www.airbnb.com/rooms/9691680
# 5552   9759181   https://www.airbnb.com/rooms/9759181
# 5553   9765083   https://www.airbnb.com/rooms/9765083
# 5554   9853331   https://www.airbnb.com/rooms/9853331
#
#                                    name property_type        room_type  \
# 0          Horto flat with small garden     Apartment  Entire home/apt
# 1               Ribeira Charming Duplex         House  Entire home/apt
# 2                     Deluxe Loft Suite     Apartment  Entire home/apt
# ...

# %%
df1.isnull().sum()
# Out:
# _id                                      0
# listing_url                              0
# name                                     8
# property_type                            0
# room_type                                0
# bed_type                                 0
# minimum_nights                           0
# maximum_nights                           0
# cancellation_policy                      0
# accommodates                             0
# bedrooms                                 5
# beds                                    13
# number_of_reviews                        0
# bathrooms                               10
# price                                    0
# cleaning_fee                          1531
# extra_people                             0
# guests_included                          0
# review_scores.review_scores_rating    1474
# dtype: int64

# %%
df1.describe()
# Out:
#                 _id  minimum_nights  maximum_nights  accommodates  \
# count  5.555000e+03     5555.000000    5.555000e+03   5555.000000
# mean   1.664386e+07        5.564356    1.382776e+06      3.505851
# std    9.622558e+06       22.613861    5.256920e+07      2.297019
# min    1.170800e+04        1.000000    1.000000e+00      1.000000
# 25%    8.376039e+06        1.000000    5.900000e+01      2.000000
# 50%    1.711345e+07        2.000000    1.125000e+03      3.000000
# 75%    2.461229e+07        3.000000    1.125000e+03      4.000000
# max    3.295874e+07     1250.000000    2.147484e+09     16.000000
#
#           bedrooms         beds  number_of_reviews    bathrooms         price  \
# count  5550.000000  5542.000000        5555.000000  5545.000000   5555.000000
# mean      1.411712     2.071454          27.606481     1.291163    278.766157
# std       1.041942     1.619660          49.798376     0.702265    842.215531
# ...

# %%
#handling Null value columns
#bedrooms
#beds
#cleaning_fee
#bathrooms
#review_rating

# %%
df1["cleaning_fee"]=df1["cleaning_fee"].fillna(0)
df1['beds']= df1['beds'].fillna(0)
df1['bedrooms']=df1['bedrooms'].fillna(0)
df1['bathrooms']= df1['bathrooms'].fillna(0)
df1['review_scores.review_scores_rating']= df1['review_scores.review_scores_rating'].fillna(0)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5752\2956397327.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["cleaning_fee"]=df1["cleaning_fee"].fillna(0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5752\2956397327.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['beds']= df1['beds'].fillna(0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5752\2956397327.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df1.isnull().sum()
# Out:
# _id                                   0
# listing_url                           0
# name                                  8
# property_type                         0
# room_type                             0
# bed_type                              0
# minimum_nights                        0
# maximum_nights                        0
# cancellation_policy                   0
# accommodates                          0
# bedrooms                              0
# beds                                  0
# number_of_reviews                     0
# bathrooms                             0
# price                                 0
# cleaning_fee                          0
# extra_people                          0
# guests_included                       0
# review_scores.review_scores_rating    0
# dtype: int64

# %%
df=df.dropna(subset=['name'])

# %%
df1.isnull().sum()
# Out:
# _id                                   0
# listing_url                           0
# name                                  8
# property_type                         0
# room_type                             0
# bed_type                              0
# minimum_nights                        0
# maximum_nights                        0
# cancellation_policy                   0
# accommodates                          0
# bedrooms                              0
# beds                                  0
# number_of_reviews                     0
# bathrooms                             0
# price                                 0
# cleaning_fee                          0
# extra_people                          0
# guests_included                       0
# review_scores.review_scores_rating    0
# dtype: int64

# %%
#converting data types

df1.dtypes
# Out:
# _id                                     int64
# listing_url                            object
# name                                   object
# property_type                          object
# room_type                              object
# bed_type                               object
# minimum_nights                          int64
# maximum_nights                          int64
# cancellation_policy                    object
# accommodates                            int64
# bedrooms                              float64
# beds                                  float64
# number_of_reviews                       int64
# bathrooms                             float64
# price                                 float64
# cleaning_fee                          float64
# extra_people                          float64
# guests_included                         int64
# review_scores.review_scores_rating    float64
# dtype: object

# %%
df1["bedrooms"]= df1["bedrooms"].astype(int)
df1["beds"]= df1["beds"].astype(int)
df1["bathrooms"]= df1["bathrooms"].astype(int)
df1["price"]= df1["price"].astype(int)
df1["extra_people"]= df1["extra_people"].astype(int)
df1["guests_included"]= df1["guests_included"].astype(int)
df1["cleaning_fee"]= df1["cleaning_fee"].astype(int)
df1['review_scores.review_scores_rating']=df1['review_scores.review_scores_rating'].astype(int)

# %%
df1.dtypes
# Out:
# _id                                    int64
# listing_url                           object
# name                                  object
# property_type                         object
# room_type                             object
# bed_type                              object
# minimum_nights                         int64
# maximum_nights                         int64
# cancellation_policy                   object
# accommodates                           int64
# bedrooms                               int64
# beds                                   int64
# number_of_reviews                      int64
# bathrooms                              int64
# price                                  int64
# cleaning_fee                           int64
# extra_people                           int64
# guests_included                        int64
# review_scores.review_scores_rating     int64
# dtype: object

# %%
df_host= df[['_id','host.host_id','host.host_name','host.host_url','host.host_location',
             'host.host_response_time','host.host_response_rate','host.host_thumbnail_url','host.host_picture_url',
             'host.host_neighbourhood','host.host_is_superhost','host.host_has_profile_pic','host.host_identity_verified',
             'host.host_listings_count','host.host_total_listings_count']]
df_host.head(2)
# Out:
#         _id  host.host_id host.host_name  \
# 0  10009999       1282196          Ynaie
# 1  10006546      51399391    Ana&Gonçalo
#
#                                 host.host_url  \
# 0   https://www.airbnb.com/users/show/1282196
# 1  https://www.airbnb.com/users/show/51399391
#
#                                 host.host_location host.host_response_time  \
# 0  Rio de Janeiro, State of Rio de Janeiro, Brazil                     NaN
# 1                  Porto, Porto District, Portugal          within an hour
#
#    host.host_response_rate                            host.host_thumbnail_url  \
# 0                      NaN  https://a0.muscache.com/im/pictures/9681e3cc-4...
# 1                    100.0  https://a0.muscache.com/im/pictures/fab79f25-2...
#
#                                host.host_picture_url host.host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/9681e3cc-4...         Jardim Botânico
# ...

# %%
                                               
# df_host['host.host_verifications']= df[['host.host_verifications[0]','host.host_verifications[1]',
#                                                                                  'host.host_verifications[2]',
#                                                                                  'host.host_verifications[3]',
#                                                                                  'host.host_verifications[4]',
#                                                                                  'host.host_verifications[5]',
#                                                                                  'host.host_verifications[6]',
#                                                                                  'host.host_verifications[7]'
#                                                                                  ]].agg(lambda x: ','.join(str(i) for i in x), axis=1)

# df_host['host.host_verifications']

# %%
df_host.isnull().sum()
# Out:
# _id                                  0
# host.host_id                         0
# host.host_name                       0
# host.host_url                        0
# host.host_location                   8
# host.host_response_time           1382
# host.host_response_rate           1382
# host.host_thumbnail_url              0
# host.host_picture_url                0
# host.host_neighbourhood           1919
# host.host_is_superhost               0
# host.host_has_profile_pic            0
# host.host_identity_verified          0
# host.host_listings_count             0
# host.host_total_listings_count       0
# dtype: int64

# %%
# Handling null values in Host dataframe
df_host["host.host_location"].fillna("Not Specified",inplace=True)

df_host["host.host_response_time"].fillna("Not Specified",inplace=True)
df_host["host.host_response_rate"].fillna("Not Specified",inplace = True)
df_host["host.host_neighbourhood"]= df_host["host.host_neighbourhood"].replace({'':"Not Specified"})
df_host["host.host_neighbourhood"].fillna("Not Specified",inplace = True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5752\1029898848.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_host["host.host_location"].fillna("Not Specified",inplace=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5752\1029898848.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df_host.isnull().sum()
# Out:
# _id                               0
# host.host_id                      0
# host.host_name                    0
# host.host_url                     0
# host.host_location                0
# host.host_response_time           0
# host.host_response_rate           0
# host.host_thumbnail_url           0
# host.host_picture_url             0
# host.host_neighbourhood           0
# host.host_is_superhost            0
# host.host_has_profile_pic         0
# host.host_identity_verified       0
# host.host_listings_count          0
# host.host_total_listings_count    0
# dtype: int64

# %%
# Changing the "True" or "False" features

df_host["host.host_is_superhost"]= df_host["host.host_is_superhost"].map({False: "No", True: "Yes"})
df_host["host.host_has_profile_pic"]= df_host["host.host_has_profile_pic"].map({False: "No", True: "Yes"})
df_host["host.host_identity_verified"]= df_host["host.host_identity_verified"].map({False: "No", True: "Yes"})
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5752\935357809.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_host["host.host_is_superhost"]= df_host["host.host_is_superhost"].map({False: "No", True: "Yes"})
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5752\935357809.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_host["host.host_has_profile_pic"]= df_host["host.host_has_profile_pic"].map({False: "No", True: "Yes"})
# ...

# %%
df_host.head(10)
# Out:
#         _id  host.host_id host.host_name  \
# 0  10009999       1282196          Ynaie
# 1  10006546      51399391    Ana&Gonçalo
# 2  10057826      47554473            Mae
# 3  10038496      51530266    Ana Valéria
# 4  10082307      51289938            Ken
# 5  10083468      27518920          Fábio
# 6  10057447      51612949     Konstantin
# 7  10047964       1241644         Zeynep
# 8  10021707      11275734           Josh
# 9  10069642      51670240       Jonathan
#
#                                 host.host_url  \
# 0   https://www.airbnb.com/users/show/1282196
# 1  https://www.airbnb.com/users/show/51399391
# 2  https://www.airbnb.com/users/show/47554473
# 3  https://www.airbnb.com/users/show/51530266
# 4  https://www.airbnb.com/users/show/51289938
# 5  https://www.airbnb.com/users/show/27518920
# 6  https://www.airbnb.com/users/show/51612949
# 7   https://www.airbnb.com/users/show/1241644
# 8  https://www.airbnb.com/users/show/11275734
# ...

# %%
df_address = df.iloc[:,137:147]
df_address = df_address.rename(columns={'address.location.coordinates[0]':'longitude','address.location.coordinates[1]':'latitude'})
df_address.head(2)
# Out:
#                            address.street   address.suburb  \
# 0  Rio de Janeiro, Rio de Janeiro, Brazil  Jardim Botânico
# 1                  Porto, Porto, Portugal              NaN
#
#                              address.government_area  address.market  \
# 0                                    Jardim Botânico  Rio De Janeiro
# 1  Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...           Porto
#
#   address.country address.country_code address.location.type  longitude  \
# 0          Brazil                   BR                 Point  -43.23075
# 1        Portugal                   PT                 Point   -8.61308
#
#     latitude  address.location.is_location_exact
# 0 -22.966254                                True
# 1  41.141300                               False

# %%
df_address.isnull().sum()
# Out:
# address.street                          0
# address.suburb                        887
# address.government_area                 0
# address.market                          6
# address.country                         0
# address.country_code                    0
# address.location.type                   0
# longitude                               0
# latitude                                0
# address.location.is_location_exact      0
# dtype: int64

# %%
#handling empty values and replace them with not specified
df_address1 = df_address.iloc[:,:-1]
df_address1.replace('', np.nan, inplace=True)
df_address1.fillna('Not Specified', inplace=True)

df_address1["address.location.is_location_exact"]=df_address["address.location.is_location_exact"]


df_address1.head(2)
df_address1["address.location.is_location_exact"]
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 5550     True
# 5551    False
# 5552     True
# 5553     True
# 5554     True
# Name: address.location.is_location_exact, Length: 5547, dtype: bool

# %%
df_address1["address.location.is_location_exact"]= df_address1["address.location.is_location_exact"].map({False:"No", True:"Yes"})
df_address1.insert(0,'_id',df['_id'])
df_address1
# Out:
#            _id                          address.street   address.suburb  \
# 0     10009999  Rio de Janeiro, Rio de Janeiro, Brazil  Jardim Botânico
# 1     10006546                  Porto, Porto, Portugal    Not Specified
# 2     10057826             Brooklyn, NY, United States       Greenpoint
# 3     10038496  Rio de Janeiro, Rio de Janeiro, Brazil       Copacabana
# 4     10082307           Hong Kong, Kowloon, Hong Kong    Yau Tsim Mong
# ...        ...                                     ...              ...
# 5550   9614672             New York, NY, United States          Midtown
# 5551   9691680              Beşiktaş, İstanbul, Turkey         Beşiktaş
# 5552   9759181               Queens, NY, United States           Queens
# 5553   9765083  Rio de Janeiro, Rio de Janeiro, Brazil         Flamengo
# 5554   9853331  Rio de Janeiro, Rio de Janeiro, Brazil           Leblon
#
#                                 address.government_area  address.market  \
# ...

# %%
df_availability = df[['_id','availability.availability_30','availability.availability_60','availability.availability_90','availability.availability_365']]
df_availability
# Out:
#            _id  availability.availability_30  availability.availability_60  \
# 0     10009999                             0                             0
# 1     10006546                            28                            47
# 2     10057826                            30                            31
# 3     10038496                             7                            19
# 4     10082307                            30                            60
# ...        ...                           ...                           ...
# 5550   9614672                             0                             0
# 5551   9691680                             0                             0
# 5552   9759181                            15                            30
# 5553   9765083                             0                             0
# 5554   9853331                             7                            37
#
#       availability.availability_90  availability.availability_365
# ...

# %%
df_availability.isnull().sum()
# Out:
# _id                              0
# availability.availability_30     0
# availability.availability_60     0
# availability.availability_90     0
# availability.availability_365    0
# dtype: int64

# %%
# Merging All data frames

df_final = pd.merge(df1, df_host, on='_id')
df_final = pd.merge(df_final,df_address1, on='_id')
df_final= pd.merge(df_final,df_availability,on='_id')

df_final.head(2)
# Out:
#         _id                            listing_url  \
# 0  10009999  https://www.airbnb.com/rooms/10009999
# 1  10006546  https://www.airbnb.com/rooms/10006546
#
#                            name property_type        room_type  bed_type  \
# 0  Horto flat with small garden     Apartment  Entire home/apt  Real Bed
# 1       Ribeira Charming Duplex         House  Entire home/apt  Real Bed
#
#    minimum_nights  maximum_nights cancellation_policy  accommodates  ...  \
# 0               2            1125            flexible             4  ...
# 1               2              30            moderate             8  ...
#
#    address.country  address.country_code  address.location.type  longitude  \
# 0           Brazil                    BR                  Point  -43.23075
# 1         Portugal                    PT                  Point   -8.61308
#
#     latitude  address.location.is_location_exact  \
# 0 -22.966254                                 Yes
# ...

# %%
# Convert final dataframe as csv file.

df_final.to_csv('Airbnb_analysis_finaldata', index = False)

# %%
df_test = pd.read_csv('D:/Data science projects/Airbnb Analysis/Airbnb_analysis_finaldata')
df_test
# Out:
#            _id                            listing_url  \
# 0     10009999  https://www.airbnb.com/rooms/10009999
# 1     10006546  https://www.airbnb.com/rooms/10006546
# 2     10057826  https://www.airbnb.com/rooms/10057826
# 3     10038496  https://www.airbnb.com/rooms/10038496
# 4     10082307  https://www.airbnb.com/rooms/10082307
# ...        ...                                    ...
# 5542   9614672   https://www.airbnb.com/rooms/9614672
# 5543   9691680   https://www.airbnb.com/rooms/9691680
# 5544   9759181   https://www.airbnb.com/rooms/9759181
# 5545   9765083   https://www.airbnb.com/rooms/9765083
# 5546   9853331   https://www.airbnb.com/rooms/9853331
#
#                                    name property_type        room_type  \
# 0          Horto flat with small garden     Apartment  Entire home/apt
# 1               Ribeira Charming Duplex         House  Entire home/apt
# 2                     Deluxe Loft Suite     Apartment  Entire home/apt
# ...
